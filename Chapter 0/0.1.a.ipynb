# %% [markdown]
# $$f = Θ(g)$$

# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(1, 1000, 1)

plt.plot(n, [f(n) for n in x])
plt.plot(n, [g(n) for n in x])
plt.text(100, 200, 'n - 100')
plt.text(700, 400, 'n - 200')
plt.ylabel('f(n)')
plt.xlabel('n')
plt.show()

# %%
def f(n):
    return n - 100;

# %%
def g(n):
    return n - 200;
