# %% [markdown]
# Functions:
#
# f(n) = n^1.01
#
# g(n) = n(log(n))^2
#
# Solution: f = Θ(g)

# %%
from math import log

# %%
def f(n):
    return n ** 1.01

# %%
def g(n):
    return n * (log(n) ** 2)

# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(1, 1400000, 1)

plt.xkcd()
plt.plot(n, [f(i) for i in n], label='f(n)')
plt.plot(n, [g(i) for i in n], label='g(n)')
plt.plot(n, [500 * f(i) for i in n], label='500 * f(n)')
plt.ylabel('f(n)')
plt.xlabel('n')
plt.legend(loc='upper left')
plt.show()
